# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudarshan0851/python_notes_by_sudarshan/blob/main/python_coding_practice_questions_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loops

# %% [markdown]
# Given a number N, print the sum of the squares of its digits. Input Size : 1 <= N <= 1000000000000000000
#
# Sample Testcase :
#
# INPUT
#
# 19
#
# OUTPUT
#
# 82

# %% [markdown]
# Write a code to get an integer N and print the sum of values from 1 to N.
#
# Input Description:
#
# A single line contains an integer N.
#
# Output Description:
#
# Print the sum of values from 1 to N.
#
# Sample Input :
#
# 10
#
# Sample Output :
#
# 55

# %% [markdown]
# Write a code get an integer number as input and print the sum of the digits.
#
# Input Description:
#
# A single line containing an integer.
#
# Output Description:
#
# Print the sum of the digits of the integer.
#
# Sample Input :
#
# 124
#
# Sample Output :
#
# 7

# %% [markdown]
# Given a number 'N' print the sum of each digit to the power of number of digits in given input.
#
# Example :
#
# Input => 1234 => ( 1 ^ 4 ) + ( 2 ^ 4 ) + ( 3 ^ 4 ) + ( 4 ^ 4 ) => 1 + 16 + 81 + 256 Output => 354
#
# N <=100000000000
#
# Sample Testcase :
#
# INPUT
#
# 1234
#
# OUTPUT
#
# 354

# %% [markdown]
# Given a number N, find the factorial of N.
#
# Input Size : 1 <= N <= 25
#
# Sample Testcase :
#
# INPUT
#
# 5
#
# OUTPUT
#
# 120

# %% [markdown]
# Given a number N in decimal convert it into binary value.
#
# Input Size : N <= 100000
#
# Sample Testcase :
#
# INPUT
#
# 5
#
# OUTPUT
#
# 101
